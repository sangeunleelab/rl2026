# %% [markdown]
# ## 밴디트 문제

# %%
import numpy as np
# import matplotlib.pyplot as plt

# %%
np.random.seed(0)
rewards = []

for n in range(1, 11):
    reward = np.random.rand()
    rewards.append(reward)
    Q = sum(rewards) / n
    print(Q)

print('---')
# Out:
# 0.5488135039273248
# 0.6320014351498722
# 0.6222554154571295
# 0.6029123573420713
# 0.567060845741438
# 0.5801997236289743
# 0.5598265075766483
# 0.6013198192273272
# 0.6415801460355164
# 0.6157662833145425
# ---
